# %%
# Pandas : In computer programming, pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structure and operations for manipulating numerical tables and time series.
# Gives power to data analyst, we can ask any question.

# There are two datastructure : DataFrame and Series.
# Dataframe -> Table
# Series -> Only single row or column

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('matches.csv')
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# Some Basic Attributes and Functions
df.head() # Gives top 5 rows from data frame
df.head(2) # Only top 2 rows
df.tail() # Last 5 rows
df.tail(3) # Last 3 rows
# Out:
#       id  season       city        date                team1  \
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2            toss_winner toss_decision  result  \
# 633        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 634          Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
# 635  Royal Challengers Bangalore    Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 633           0  Sunrisers Hyderabad           22               0
# 634           0  Sunrisers Hyderabad            0               4
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1        umpire2  \
# ...

# %%
# How many rows and columns in data ?
df.shape # tuple, 1st element gives rows and 2nd columns
# Out:
# (636, 18)

# %%
df.info() # Preview of data
# Object is most likely to be a string in pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.6+ KB

# %%
df.describe() # Works only on numerical values
# It gives higher mathematical analysis on data
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
# Fetching rows and columns
print(df['winner']) # For fetching single column (series)
type(df['winner'])
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object
# pandas.core.series.Series

# %%
# To fetch multiple columns
print(df[['team1', 'team2', 'winner']])
type(df[['team1', 'team2', 'winner']])
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
# To fetch rows
df.iloc[1] # Fetches 1st row (Series)
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
df.iloc[1:3] # Gives 1 and 2 row, and it will be a dataframe
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
df.iloc[1:11:2] # To get alternate rows (patter)
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.iloc[[1,5,6]] # Fancy Indexing
# Out:
#    id  season       city        date                  team1  \
# 1   2    2017       Pune  2017-04-06         Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09  Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 6           0          Mumbai Indians            0               4
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
# We can fetch columns too
df.iloc[:,[4, 5, 10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df.iloc[0:100:5,[4, 5, 10]]
# Out:
#                      team1                        team2  \
# 0      Sunrisers Hyderabad  Royal Challengers Bangalore
# 5            Gujarat Lions          Sunrisers Hyderabad
# 10         Kings XI Punjab        Kolkata Knight Riders
# 15           Gujarat Lions               Mumbai Indians
# 20     Sunrisers Hyderabad             Delhi Daredevils
# 25         Kings XI Punjab                Gujarat Lions
# 30        Delhi Daredevils        Kolkata Knight Riders
# 35     Sunrisers Hyderabad        Kolkata Knight Riders
# 40           Gujarat Lions             Delhi Daredevils
# 45         Kings XI Punjab                Gujarat Lions
# 50        Delhi Daredevils       Rising Pune Supergiant
# 55  Rising Pune Supergiant               Mumbai Indians
# 60     Chennai Super Kings              Kings XI Punjab
# 65         Deccan Chargers             Delhi Daredevils
# 70   Kolkata Knight Riders          Chennai Super Kings
# 75        Delhi Daredevils  Royal Challengers Bangalore
# ...

# %%
# Filtering Data Frame (Fetching rows based on condition)

# Rows where matches were played in hyderabad
mask = df['city'] == 'Hyderabad'
mask # Boolean Series
df[mask] # Masking this boolean series on dataframe, only where condition is True is printed.
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
mask1 = df['city'] == 'Hyderabad'
mask2 = df['date'] > '2010-01-01'

df[mask1 & mask2]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %%
# Values count

# Har team ne kitne matches jeete hain
# In one column it counts frequeny

df['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
# plot() Function (Data Visualization)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df['winner'].value_counts().plot(kind = 'bar')

# %%
df['toss_decision'].value_counts().plot(kind = 'pie')

# %%
df['win_by_runs'].plot(kind = 'hist')

# %%
# Series Operations

# %%
myseries = df['winner'].value_counts()
myseries.index # Gives index of series
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
myseries.values # Gives all the values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
myseries['Gujarat Lions']
# Out:
# 13

# %%
df['team2'].value_counts() + df['team1'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %%
# Sort Values Method

# %%
(df['team2'].value_counts() + df['team1'].value_counts()).sort_values(ascending = False) # By default ascending order
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
df.sort_values('city', ascending = False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
df.sort_values('city', ascending = False, inplace = True) # To make changes permanent

# %%
# To sort on multiple values
df.sort_values(['city', 'date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
df.sort_values(['city', 'date'], ascending = [True, False])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b12e5f95af7> in <module>
# ----> 1 df.sort_values(['city', 'date'], ascending = [True, False])
#
# NameError: name 'df' is not defined

# %%
# drop_duplicates() functions :
# We do not send duplicate data to our machine learning model
df.drop_duplicates(subset = ['city']) # It gives unique value of cities
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
df.drop_duplicates(subset = ['city'], keep = "last")
# Out:
#       id  season            city        date                        team1  \
# 129  130    2009       Cape Town  2009-04-26              Kings XI Punjab
# 149  150    2009     East London  2009-05-08               Mumbai Indians
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# 161  162    2009  Port Elizabeth  2009-05-16               Mumbai Indians
# 164  165    2009    Bloemfontein  2009-05-17             Delhi Daredevils
# 168  169    2009          Durban  2009-05-20          Chennai Super Kings
# 171  172    2009       Centurion  2009-05-22             Delhi Daredevils
# 173  174    2009    Johannesburg  2009-05-24              Deccan Chargers
# 219  220    2010          Nagpur  2010-04-12              Deccan Chargers
# 277  278    2011           Kochi  2011-05-05         Kochi Tuskers Kerala
# 293  294    2011          Indore  2011-05-15             Rajasthan Royals
# 441  442    2013          Jaipur  2013-05-12          Chennai Super Kings
# ...

# %%
# We have inplace parameter in drop_duplicates() function too, if we set it true our actucal dataframe gets changes

# %%
df.drop_duplicates(subset = ['city', 'season']).shape # Applying drop_duplicates() on multple columns
# Out:
# (107, 18)

# %%
df.drop_duplicates(subset = ['season'], keep = "last")[['season', 'winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %%
# The Groupby() function
company = pd.read_csv('Fortune500CompaniesUS.csv', encoding='latin-1')
company
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
# Making groups in existing data, applies on categorical data
venue = df.groupby("venue")

# %%
len(venue) # How many different venues.
# Out:
# 35

# %%
venue.size() # Venue ka size in terms no of times venue was selected, it is sorted on the basis of index
venue.size().sort_values(ascending = False)
# Out:
# venue
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# Brabourne Stadium                                       11
# ...

# %%
venue.first() # Gives 1st occurence of venue
# Out:
#                                                      id  season  \
# venue
# Barabati Stadium                                    186    2010
# Brabourne Stadium                                   176    2010
# Buffalo Park                                        138    2009
# De Beers Diamond Oval                               151    2009
# Dr DY Patil Sports Academy                           72    2008
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  313    2012
# Dubai International Cricket Stadium                 462    2014
# Eden Gardens                                         11    2017
# Feroz Shah Kotla                                     15    2017
# Green Park                                           49    2017
# Himachal Pradesh Cricket Association Stadium        225    2010
# Holkar Cricket Stadium                                4    2017
# JSCA International Stadium Complex                  441    2013
# ...

# %%
venue.last() # Gives last occurence ofvenue
# Out:
#                                                      id  season  \
# venue
# Barabati Stadium                                    497    2014
# Brabourne Stadium                                   570    2015
# Buffalo Park                                        150    2009
# De Beers Diamond Oval                               155    2009
# Dr DY Patil Sports Academy                          298    2011
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  629    2016
# Dubai International Cricket Stadium                 477    2014
# Eden Gardens                                        631    2016
# Feroz Shah Kotla                                    635    2016
# Green Park                                          630    2016
# Himachal Pradesh Cricket Association Stadium        450    2013
# Holkar Cricket Stadium                              294    2011
# JSCA International Stadium Complex                  575    2015
# ...

# %%
venue.groups # Dictonary where the key is name of venue and value is list with id of matches
# Out:
# {'Barabati Stadium': Int64Index([185, 188, 336, 347, 485, 490, 496], dtype='int64'),
#  'Brabourne Stadium': Int64Index([175, 187, 190, 193, 200, 206, 220, 514, 552, 557, 569], dtype='int64'),
#  'Buffalo Park': Int64Index([137, 143, 149], dtype='int64'),
#  'De Beers Diamond Oval': Int64Index([150, 151, 154], dtype='int64'),
#  'Dr DY Patil Sports Academy': Int64Index([ 71,  81,  85, 116, 174, 198, 230, 231, 232, 233, 238, 243, 249,
#              263, 276, 294, 297],
#             dtype='int64'),
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': Int64Index([312, 315, 528, 530, 536, 612, 615, 618, 622, 624, 628], dtype='int64'),
#  'Dubai International Cricket Stadium': Int64Index([461, 462, 466, 468, 469, 474, 476], dtype='int64'),
#  'Eden Gardens': Int64Index([ 10,  13,  22,  26,  30,  39,  52,  63,  74,  87,  94, 102, 104,
#              111, 177, 181, 203, 207, 212, 226, 229, 239, 250, 254, 257, 269,
# ...

# %%
df.iloc[185, :]
# Out:
# id                              186
# season                         2010
# city                        Cuttack
# date                     2010-03-19
# team1               Deccan Chargers
# team2               Kings XI Punjab
# toss_winner         Kings XI Punjab
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner              Deccan Chargers
# win_by_runs                       6
# win_by_wickets                    0
# player_of_match           A Symonds
# venue              Barabati Stadium
# umpire1                   BF Bowden
# umpire2                   M Erasmus
# umpire3                         NaN
# Name: 185, dtype: object

# %%
venue.get_group('Eden Gardens') # Gives Eden Garden dataframe, returns everything except venue
# Out:
#       id  season     city        date                    team1  \
# 10    11    2017  Kolkata  2017-04-13          Kings XI Punjab
# 13    14    2017  Kolkata  2017-04-15    Kolkata Knight Riders
# 22    23    2017  Kolkata  2017-04-21    Kolkata Knight Riders
# 26    27    2017  Kolkata  2017-04-23    Kolkata Knight Riders
# 30    31    2017  Kolkata  2017-04-28         Delhi Daredevils
# ..   ...     ...      ...         ...                      ...
# 607  608    2016  Kolkata  2016-05-04    Kolkata Knight Riders
# 613  614    2016  Kolkata  2016-05-08    Kolkata Knight Riders
# 620  621    2016  Kolkata  2016-05-14  Rising Pune Supergiants
# 623  624    2016  Kolkata  2016-05-16    Kolkata Knight Riders
# 630  631    2016  Kolkata  2016-05-22    Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 10         Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
venue.sum() # All numerical values gets calculated on the basis of groups
# Out:
#                                                        id  season  dl_applied  \
# venue
# Barabati Stadium                                     2534   14086           0
# Brabourne Stadium                                    3574   22129           0
# Buffalo Park                                          432    6027           0
# De Beers Diamond Oval                                 458    6027           0
# Dr DY Patil Sports Academy                           3528   34169           0
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...   5951   22165           2
# Dubai International Cricket Stadium                  3283   14098           0
# Eden Gardens                                        19973  122783           3
# Feroz Shah Kotla                                    19600  120771           2
# Green Park                                           1358    8066           0
# Himachal Pradesh Cricket Association Stadium         2949   18103           0
# ...

# %%
venue.mean()
# Out:
#                                                             id       season  \
# venue
# Barabati Stadium                                    362.000000  2012.285714
# Brabourne Stadium                                   324.909091  2011.727273
# Buffalo Park                                        144.000000  2009.000000
# De Beers Diamond Oval                               152.666667  2009.000000
# Dr DY Patil Sports Academy                          207.529412  2009.941176
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  541.000000  2015.000000
# Dubai International Cricket Stadium                 469.000000  2014.000000
# Eden Gardens                                        327.426230  2012.836066
# Feroz Shah Kotla                                    326.666667  2012.850000
# Green Park                                          339.500000  2016.500000
# Himachal Pradesh Cricket Association Stadium        327.666667  2011.444444
# ...

# %%
venue['win_by_runs'].mean()
# Out:
# venue
# Barabati Stadium                                        10.428571
# Brabourne Stadium                                       12.363636
# Buffalo Park                                            29.000000
# De Beers Diamond Oval                                   17.666667
# Dr DY Patil Sports Academy                              11.588235
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     25.636364
# Dubai International Cricket Stadium                      3.714286
# Eden Gardens                                             9.622951
# Feroz Shah Kotla                                        14.600000
# Green Park                                               0.000000
# Himachal Pradesh Cricket Association Stadium            31.000000
# Holkar Cricket Stadium                                   0.000000
# JSCA International Stadium Complex                       5.857143
# Kingsmead                                               10.600000
# ...

# %%
delivery = pd.read_csv('deliveries.csv')
delivery
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
# Q) Find 5 batsman who scored most runs.
batsman = delivery.groupby('batsman')
batsman.sum()['batsman_runs'].sort_values(ascending = False).head()
# Out:
# batsman
# V Kohli      5434
# SK Raina     5415
# RG Sharma    4914
# DA Warner    4741
# S Dhawan     4632
# Name: batsman_runs, dtype: int64

# %%
# Q) To findout batsman who hit sabse jyda chauke
mask = delivery['batsman_runs'] == 6
new_delivery = delivery[mask]
new_delivery.shape[0] # This much six's in ipl
# Out:
# 8170

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending = False).head()
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# Name: batsman_runs, dtype: int64

# %%
new_delivery.groupby('batsman').size().sort_values(ascending = False).head()
# Out:
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# dtype: int64

# %%
# Virat Kholi ne kin 3 teams k against sabse jyda runs maare
vk = delivery[delivery['batsman']=='V Kohli']
vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending = False).head(3)
# Out:
# bowling_team
# Delhi Daredevils         763
# Chennai Super Kings      749
# Kolkata Knight Riders    675
# Name: batsman_runs, dtype: int64

# %%
def runs_scored(batsmanName) :
    vk = delivery[delivery['batsman']==batsmanName]
    return(vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending = False).index[0])

# %%
runs_scored('V Kohli')
# Out:
# 'Delhi Daredevils'

# %%
# Rename Columns
df
df.rename(columns={'city' : 'place', 'date' : 'dom'})
# Out:
#       id  season      place         dom                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# isin() function :-
# Find the most destructive death over batsman in the history of IPL ?
# Soln : 
# Strike Rate = (Number of runs / Number of balls)/100
# Min batsman 200 balls in over 16-20

# %%
delivery = pd.read_csv('deliveries.csv')

# %%
death_over = delivery[delivery['over'] > 15]
all_batsman = death_over.groupby('batsman')['batsman_runs'].count()
x = all_batsman > 200
batsman_list = all_batsman[x].index.tolist()

# %%
# Runs scored by all these 43 batsman
# Balls played by these 43 batsman

final = delivery[delivery['batsman'].isin(batsman_list)]

# %%
runs = final.groupby('batsman')['batsman_runs'].sum()
balls = final.groupby('batsman')['batsman_runs'].count()
sr = (runs/balls)*100
sr.sort_values(ascending = False)
# Out:
# batsman
# AD Russell          179.950187
# RR Pant             162.318841
# CH Morris           153.392330
# HH Pandya           151.902174
# AB de Villiers      148.740343
# CH Gayle            145.640370
# KH Pandya           144.094488
# KA Pollard          141.751527
# DA Warner           139.523249
# YK Pathan           138.860326
# KL Rahul            137.406143
# SR Watson           136.945813
# JA Morkel           136.938202
# DA Miller           136.264535
# MS Dhoni            134.930681
# SK Raina            133.902077
# Harbhajan Singh     131.962025
# JP Faulkner         129.802956
# SV Samson           129.340278
# V Kohli             129.042983
# WP Saha             128.798842
# RG Sharma           128.773585
# KD Karthik          127.612457
# RV Uthappa          127.319588
# SPD Smith           126.670792
# STR Binny           126.000000
# DJ Bravo            125.565801
# Yuvraj Singh        125.283190
# KM Jadhav           124.118316
# AT Rayudu           124.058187
# ...

# %%
# Merge Function
# List of Orange Cap Holder
new = delivery.merge(df, left_on='match_id', right_on='id')
new.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending = False).reset_index().drop_duplicates(subset = 'season', keep = 'first').sort_values("season")[['season', 'batsman']] # MultiIndexed Series
# Out:
#     season       batsman
# 10    2008      SE Marsh
# 13    2009     ML Hayden
# 9     2010  SR Tendulkar
# 11    2011      CH Gayle
# 2     2012      CH Gayle
# 3     2013    MEK Hussey
# 6     2014    RV Uthappa
# 17    2015     DA Warner
# 0     2016       V Kohli
# 7     2017     DA Warner

# %%
# Pivot Table
mask = delivery['batsman_runs'] == 6
six = delivery[mask]

# %%
pt = six.pivot_table(index = 'over', columns = 'batting_team', values = 'batsman_runs', aggfunc = 'count')
# Pivot table to heatmap
import seaborn as sns
sns.heatmap(pt)

# %%
# Cor-relation function
# Relation between two numeric values
df.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN
